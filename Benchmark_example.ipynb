# %%
import lancet, re

# %%
benchmark_name   = 'gpu_benchmark'
cortex_density = lancet.List('cortex_density', [48, 142, 162])
iterations = lancet.List('iterations', [1000])
resource=lancet.List('gpu',[True])  
executable = '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/timing_script.sh'
timing_cmd     = lancet.ShellCommand(executable=executable, posargs=['cortex_density', 'iterations', 'gpu'])
p_space = cortex_density * iterations* resource
# Runs locally. A Launcher could be used to launch jobs with Grid Engine.
for i in range(20):
    lancet.Launcher(benchmark_name, p_space, timing_cmd, output_directory='benchmarks', max_concurrency=1)()
    print "Run %d finished..." % i
# Out:
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 0 finished...
# Run 1 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 2 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 3 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 4 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 5 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 6 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 7 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 8 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 9 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 10 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 11 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 12 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 13 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 14 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 15 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 16 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 17 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 18 finished...
# Time: 000000.00 Launcher: Group 0: executing 3 processes...
# Run 19 finished...

# %%
output_files   = lancet.FilePattern('timing_files', './benchmarks/*-gpu_benchmark*/streams/*_tid_{tid:d}.o*')

# %%
def parse_timings(filename):
    with open(filename, 'r') as infile:
        content = infile.read()
    
    host_m = re.search('^HOST:\t(?P<host>.*?)\n', content, re.MULTILINE)
    param_m = re.search('^PARAMS:\t(?P<cortex_density>.*?)\t(?P<iterations>.*?)\t(?P<gpu>.*?)\n', content, re.MULTILINE)
    version_m = re.search('^VERSION:\t(?P<version>.*?)\n', content, re.MULTILINE)
    timing_m = re.findall('^[0-9]*.[0-9]*u [0-9]*.[0-9]*s ([0-9]*:[0-9]*.[0-9]*) ([0-9]*.[0-9])%', content, re.MULTILINE)
    if host_m is None or param_m is None or len(timing_m) < 3:
        raise Exception("The benchmark file %s has incorrect format" % filename)
    timing_m = [(float(t.split(':')[0]) * 60 + float(t.split(':')[1]) + float('0.' + t.split('.')[1]), float(u)) for t, u in timing_m]

    result = {'topo_startup_time': timing_m[0][0], 'topo_startup_cpu': timing_m[0][1],
              'sim_startup_time': timing_m[1][0] - timing_m[0][0], 'sim_startup_cpu': timing_m[1][1],
              'sim_run_time': timing_m[-1][0] - timing_m[1][0],
              'total_time': timing_m[-1][0], 'total_cpu': timing_m[-1][1]}
    
    p = param_m.groupdict()
    p['gpu'] = True if p['gpu'] == 'True' else False
    p['iterations'] = int(p['iterations'])
    p['cortex_density'] = float(p['cortex_density'])
    result.update(host_m.groupdict())
    result.update(p)
    result.update(version_m.groupdict())
    return result

# %%
collected_timings = lancet.FileInfo(output_files, 'timing_files',
                                lancet.CustomFile(metadata_fn=parse_timings))

# %%
len(collected_timings)
# Out:
# 180

# %%
import holoviews
from holoviews import *
# %load_ext holoviews.ipython

# %output holomap='widgets' fig='svg'
# %opts Regression [apply_databounds=True]
# Out:
# Welcome to the HoloViews IPython extension! (http://ioam.github.io/holoviews/)
# Available magics: %compositor, %opts, %output, %params, %%labels, %%opts, %%output

# %% [markdown]
# # Graphing the performance differences between Topographica GPU implementation using CSR and HYB sparse matrix formats:

# %%
hyb_vs_csr = DFrame(collected_timings.dframe.loc[:, ['cortex_density', 'version', 'iterations', 'gpu', 'host', 'sim_run_time', 'total_time']].query('version in ["Streamed_GPU_Kernels_CSR_dot_only", "Streamed_GPU_Kernels_HYB_dot_only", "Streamed_GPU_Kernels"] and gpu == True'))

# %%
hyb_vs_csr.regression('cortex_density', 'sim_run_time', mdims=['version', 'iterations', 'host'], extents=(42, 0, 162, 200), reduce_fn=np.mean).overlay(['version']).layout('host')
# Out:
# NdLayout.NdLayout   [host]
#    |_ NdLayout.NdLayout

# %%
collected_timings.dframe
# Out:
#      cortex_density   gpu                 host  iterations  sim_run_time  \
# 0                48  True  melmac.inf.ed.ac.uk        1000         20.88
# 1               142  True  melmac.inf.ed.ac.uk        1000         93.88
# 2               162  True  melmac.inf.ed.ac.uk        1000        146.42
# 3                48  True  melmac.inf.ed.ac.uk        1000         21.20
# 4               142  True  melmac.inf.ed.ac.uk        1000         92.50
# 5               162  True  melmac.inf.ed.ac.uk        1000        134.72
# 6                48  True  melmac.inf.ed.ac.uk        1000         20.56
# 7               142  True  melmac.inf.ed.ac.uk        1000         92.48
# 8               162  True  melmac.inf.ed.ac.uk        1000        144.56
# 9                48  True  melmac.inf.ed.ac.uk        1000         21.62
# 10              142  True  melmac.inf.ed.ac.uk        1000         95.42
# 11              162  True  melmac.inf.ed.ac.uk        1000        142.28
# 12               48  True  melmac.inf.ed.ac.uk        1000         20.26
# 13              142  True  melmac.inf.ed.ac.uk        1000         95.36
# 14              162  True  melmac.inf.ed.ac.uk        1000        143.74
# 15               48  True  melmac.inf.ed.ac.uk        1000         20.36
# 16              142  True  melmac.inf.ed.ac.uk        1000         90.08
# 17              162  True  melmac.inf.ed.ac.uk        1000        148.56
# 18               48  True  melmac.inf.ed.ac.uk        1000         20.40
# 19              142  True  melmac.inf.ed.ac.uk        1000         93.02
# 20              162  True  melmac.inf.ed.ac.uk        1000        145.66
# 21               48  True  melmac.inf.ed.ac.uk        1000         20.90
# 22              142  True  melmac.inf.ed.ac.uk        1000         93.80
# 23              162  True  melmac.inf.ed.ac.uk        1000        140.60
# 24               48  True  melmac.inf.ed.ac.uk        1000         20.94
# 25              142  True  melmac.inf.ed.ac.uk        1000         96.06
# 26              162  True  melmac.inf.ed.ac.uk        1000        145.46
# 27               48  True  melmac.inf.ed.ac.uk        1000         21.40
# 28              142  True  melmac.inf.ed.ac.uk        1000         93.00
# 29              162  True  melmac.inf.ed.ac.uk        1000        141.72
# ..              ...   ...                  ...         ...           ...
# 150              48  True  melmac.inf.ed.ac.uk        1000         18.72
# 151             142  True  melmac.inf.ed.ac.uk        1000         66.74
# 152             162  True  melmac.inf.ed.ac.uk        1000        112.76
# 153              48  True  melmac.inf.ed.ac.uk        1000         19.02
# 154             142  True  melmac.inf.ed.ac.uk        1000         64.08
# 155             162  True  melmac.inf.ed.ac.uk        1000        112.38
# 156              48  True  melmac.inf.ed.ac.uk        1000         18.70
# 157             142  True  melmac.inf.ed.ac.uk        1000         65.18
# 158             162  True  melmac.inf.ed.ac.uk        1000        114.98
# 159              48  True  melmac.inf.ed.ac.uk        1000         18.72
# 160             142  True  melmac.inf.ed.ac.uk        1000         64.36
# 161             162  True  melmac.inf.ed.ac.uk        1000        110.88
# 162              48  True  melmac.inf.ed.ac.uk        1000         18.62
# 163             142  True  melmac.inf.ed.ac.uk        1000         66.14
# 164             162  True  melmac.inf.ed.ac.uk        1000        110.70
# 165              48  True  melmac.inf.ed.ac.uk        1000         17.50
# 166             142  True  melmac.inf.ed.ac.uk        1000         66.80
# 167             162  True  melmac.inf.ed.ac.uk        1000        116.08
# 168              48  True  melmac.inf.ed.ac.uk        1000         18.96
# 169             142  True  melmac.inf.ed.ac.uk        1000         66.38
# 170             162  True  melmac.inf.ed.ac.uk        1000        115.14
# 171              48  True  melmac.inf.ed.ac.uk        1000         19.06
# 172             142  True  melmac.inf.ed.ac.uk        1000         65.04
# 173             162  True  melmac.inf.ed.ac.uk        1000        110.52
# 174              48  True  melmac.inf.ed.ac.uk        1000         18.80
# 175             142  True  melmac.inf.ed.ac.uk        1000         66.58
# 176             162  True  melmac.inf.ed.ac.uk        1000        110.12
# 177              48  True  melmac.inf.ed.ac.uk        1000         18.42
# 178             142  True  melmac.inf.ed.ac.uk        1000         65.26
# 179             162  True  melmac.inf.ed.ac.uk        1000        111.86
#
#      sim_startup_cpu  sim_startup_time  tid  \
# 0               99.4             20.22    0
# 1               99.8            239.90    1
# 2               99.9            364.22    2
# 3               99.3             20.38    0
# 4               99.8            238.82    1
# 5               99.9            370.14    2
# 6               99.4             20.50    0
# 7               99.8            240.28    1
# 8               99.8            362.58    2
# 9               99.3             20.22    0
# 10              99.8            238.08    1
# 11              99.9            363.10    2
# 12              99.2             20.38    0
# 13              99.8            238.72    1
# 14              99.9            362.38    2
# 15              99.4             20.82    0
# 16              99.8            241.40    1
# 17              99.9            360.24    2
# 18              99.3             20.50    0
# 19              99.8            238.68    1
# 20              99.9            362.20    2
# 21              99.3             20.52    0
# 22              99.8            237.60    1
# 23              99.9            361.98    2
# 24              99.3             19.30    0
# 25              99.8            237.90    1
# 26              99.8            361.44    2
# 27              99.4             20.40    0
# 28              99.8            240.04    1
# 29              99.8            362.64    2
# ..               ...               ...  ...
# 150             99.2             17.72    0
# 151             99.8            234.96    1
# 152             99.9            359.78    2
# 153             99.2             19.52    0
# 154             99.8            236.88    1
# 155             99.9            361.28    2
# 156             99.2             19.26    0
# 157             99.8            235.32    1
# 158             99.8            359.56    2
# 159             99.2             19.00    0
# 160             99.8            236.66    1
# 161             99.8            360.86    2
# 162             99.2             19.74    0
# 163             99.8            236.22    1
# 164             99.8            359.30    2
# 165             98.4             20.28    0
# 166             99.8            236.38    1
# 167             99.8            357.78    2
# 168             99.2             19.42    0
# 169             99.8            236.24    1
# 170             99.8            358.00    2
# 171             99.0             19.54    0
# 172             99.8            236.42    1
# 173             99.8            360.80    2
# 174             99.3             19.46    0
# 175             99.8            234.22    1
# 176             99.9            361.02    2
# 177             99.2             18.26    0
# 178             99.8            236.22    1
# 179             99.8            360.00    2
#
#                                           timing_files  topo_startup_cpu  \
# 0    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.3
# 1    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 2    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.2
# 3    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 4    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 5    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              57.2
# 6    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              93.1
# 7    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 8    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 9    /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 10   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 11   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              94.8
# 12   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.3
# 13   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 14   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 15   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 16   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 17   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 18   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              98.1
# 19   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              98.1
# 20   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 21   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 22   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 23   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 24   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              80.0
# 25   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 26   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 27   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 28   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 29   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              95.5
# ..                                                 ...               ...
# 150  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              53.9
# 151  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 152  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 153  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 154  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 155  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              94.8
# 156  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 157  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 158  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 159  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              94.8
# 160  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 161  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              94.6
# 162  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.1
# 163  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 164  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              94.7
# 165  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              94.6
# 166  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 167  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.4
# 168  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              94.8
# 169  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 170  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 171  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 172  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 173  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              94.7
# 174  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.2
# 175  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.3
# 176  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              96.3
# 177  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              80.7
# 178  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              97.2
# 179  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...              95.4
#
#      topo_startup_time  total_cpu  total_time  \
# 0                 1.30      447.0       42.40
# 1                 1.12      293.8      334.90
# 2                 1.14      267.1      511.78
# 3                 1.20      445.7       42.78
# 4                 1.18      294.9      332.50
# 5                 3.38      266.5      508.24
# 6                 1.32      447.2       42.38
# 7                 1.18      294.0      333.94
# 8                 1.14      267.3      508.28
# 9                 1.14      445.0       42.98
# 10                1.18      294.0      334.68
# 11                1.32      268.1      506.70
# 12                1.30      448.3       41.94
# 13                1.20      293.3      335.28
# 14                1.14      267.9      507.26
# 15                1.12      447.7       42.30
# 16                1.14      294.9      332.62
# 17                1.18      266.8      509.98
# 18                1.16      450.2       42.06
# 19                1.12      294.7      332.82
# 20                1.12      267.1      508.98
# 21                1.16      447.0       42.58
# 22                1.18      294.6      332.58
# 23                1.14      268.9      503.72
# 24                2.62      446.0       42.86
# 25                1.18      293.0      335.14
# 26                1.18      267.2      508.08
# 27                1.18      449.2       42.98
# 28                1.16      293.6      334.20
# 29                1.26      268.9      505.62
# ..                 ...        ...         ...
# 150               3.38      436.2       39.82
# 151               1.20      251.7      302.90
# 152               1.18      264.6      473.72
# 153               1.20      438.9       39.74
# 154               1.22      251.3      302.18
# 155               1.34      264.2      475.00
# 156               1.20      434.8       39.16
# 157               1.16      251.1      301.66
# 158               1.20      263.9      475.74
# 159               1.34      435.8       39.06
# 160               1.14      251.0      302.16
# 161               1.26      264.7      473.00
# 162               1.12      437.3       39.48
# 163               1.16      250.9      303.52
# 164               1.28      265.4      471.28
# 165               1.24      436.6       39.02
# 166               1.18      249.9      304.36
# 167               1.26      264.1      475.12
# 168               1.32      437.0       39.70
# 169               1.16      250.5      303.78
# 170               1.20      264.6      474.34
# 171               1.20      436.3       39.80
# 172               1.18      250.9      302.64
# 173               1.30      265.3      472.62
# 174               1.14      436.6       39.40
# 175               1.24      251.0      302.04
# 176               1.18      265.5      472.32
# 177               2.36      435.4       39.04
# 178               1.18      250.7      302.66
# 179               1.20      264.9      473.06
#
#                                version
# 0                 Streamed_GPU_Kernels
# 1                 Streamed_GPU_Kernels
# 2                 Streamed_GPU_Kernels
# 3                 Streamed_GPU_Kernels
# 4                 Streamed_GPU_Kernels
# 5                 Streamed_GPU_Kernels
# 6                 Streamed_GPU_Kernels
# 7                 Streamed_GPU_Kernels
# 8                 Streamed_GPU_Kernels
# 9                 Streamed_GPU_Kernels
# 10                Streamed_GPU_Kernels
# 11                Streamed_GPU_Kernels
# 12                Streamed_GPU_Kernels
# 13                Streamed_GPU_Kernels
# 14                Streamed_GPU_Kernels
# 15                Streamed_GPU_Kernels
# 16                Streamed_GPU_Kernels
# 17                Streamed_GPU_Kernels
# 18                Streamed_GPU_Kernels
# 19                Streamed_GPU_Kernels
# 20                Streamed_GPU_Kernels
# 21                Streamed_GPU_Kernels
# 22                Streamed_GPU_Kernels
# 23                Streamed_GPU_Kernels
# 24                Streamed_GPU_Kernels
# 25                Streamed_GPU_Kernels
# 26                Streamed_GPU_Kernels
# 27                Streamed_GPU_Kernels
# 28                Streamed_GPU_Kernels
# 29                Streamed_GPU_Kernels
# ..                                 ...
# 150  Streamed_GPU_Kernels_HYB_dot_only
# 151  Streamed_GPU_Kernels_HYB_dot_only
# 152  Streamed_GPU_Kernels_HYB_dot_only
# 153  Streamed_GPU_Kernels_HYB_dot_only
# 154  Streamed_GPU_Kernels_HYB_dot_only
# 155  Streamed_GPU_Kernels_HYB_dot_only
# 156  Streamed_GPU_Kernels_HYB_dot_only
# 157  Streamed_GPU_Kernels_HYB_dot_only
# 158  Streamed_GPU_Kernels_HYB_dot_only
# 159  Streamed_GPU_Kernels_HYB_dot_only
# 160  Streamed_GPU_Kernels_HYB_dot_only
# 161  Streamed_GPU_Kernels_HYB_dot_only
# 162  Streamed_GPU_Kernels_HYB_dot_only
# 163  Streamed_GPU_Kernels_HYB_dot_only
# 164  Streamed_GPU_Kernels_HYB_dot_only
# 165  Streamed_GPU_Kernels_HYB_dot_only
# 166  Streamed_GPU_Kernels_HYB_dot_only
# 167  Streamed_GPU_Kernels_HYB_dot_only
# 168  Streamed_GPU_Kernels_HYB_dot_only
# 169  Streamed_GPU_Kernels_HYB_dot_only
# 170  Streamed_GPU_Kernels_HYB_dot_only
# 171  Streamed_GPU_Kernels_HYB_dot_only
# 172  Streamed_GPU_Kernels_HYB_dot_only
# 173  Streamed_GPU_Kernels_HYB_dot_only
# 174  Streamed_GPU_Kernels_HYB_dot_only
# 175  Streamed_GPU_Kernels_HYB_dot_only
# 176  Streamed_GPU_Kernels_HYB_dot_only
# 177  Streamed_GPU_Kernels_HYB_dot_only
# 178  Streamed_GPU_Kernels_HYB_dot_only
# 179  Streamed_GPU_Kernels_HYB_dot_only
#
# [180 rows x 14 columns]

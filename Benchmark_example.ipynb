# %%
import lancet, re

# %%
benchmark_name   = 'gpu_benchmark'
cortex_density = lancet.Range('cortex_density', 48, 142, steps=2, fp_precision=0)
iterations = lancet.Range('iterations', 250, 1000, steps=2, fp_precision=0)
resource=lancet.List('gpu',[True, False])  
executable = '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/timing_script.sh'
timing_cmd     = lancet.ShellCommand(executable=executable, posargs=['cortex_density', 'iterations', 'gpu'])
p_space = cortex_density * iterations* resource
# Runs locally. A Launcher could be used to launch jobs with Grid Engine.
lancet.Launcher(benchmark_name, p_space, timing_cmd, output_directory='benchmarks', max_concurrency=1)()
# Out:
# Time: 000000.00 Launcher: Group 0: executing 8 processes...

# %%
output_files   = lancet.FilePattern('timing_files', './benchmarks/*-gpu_benchmark*/streams/*_tid_{tid:d}.o*')

# %%
def parse_timings(filename):
    with open(filename, 'r') as infile:
        content = infile.read()
    
    host_m = re.search('^HOST:\t(?P<host>.*?)\n', content, re.MULTILINE)
    param_m = re.search('^PARAMS:\t(?P<cortex_density>.*?)\t(?P<iterations>.*?)\t(?P<gpu>.*?)\n', content, re.MULTILINE)
    timing_m = re.findall('^[0-9]*.[0-9]*u [0-9]*.[0-9]*s ([0-9]*:[0-9]*.[0-9]*) ([0-9]*.[0-9])%', content, re.MULTILINE)
    if host_m is None or param_m is None or len(timing_m) is not 4:
        raise Exception("The benchmark file %s has incorrect format" % filename)
    timing_m = [(float(t.split(':')[0]) * 60 + float(t.split(':')[1]) + float('0.' + t.split('.')[1]), float(u)) for t, u in timing_m]

    result = {'startup_time': timing_m[0][0], 'startup_cpu': timing_m[0][1],
              'running_0_time': timing_m[1][0], 'running_0_cpu': timing_m[1][1],
              'running_1_time': timing_m[2][0], 'running_1_cpu': timing_m[2][1],
              'running_full_time': timing_m[3][0], 'running_full_cpu': timing_m[3][1]}
    result.update(host_m.groupdict())
    result.update(param_m.groupdict())
    return result

# %%
collected_timings = lancet.FileInfo(output_files, 'timing_files',
                                lancet.CustomFile(metadata_fn=parse_timings))

# %%
len(collected_timings)
# Out:
# 26

# %%
collected_timings.specs
# Out:
# [{'cortex_density': '48',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 99.0,
#   'running_0_time': 22.42,
#   'running_1_cpu': 102.8,
#   'running_1_time': 22.74,
#   'running_full_cpu': 240.9,
#   'running_full_time': 27.78,
#   'startup_cpu': 98.0,
#   'startup_time': 1.02,
#   'tid': 0,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1559-gpu_benchmark/streams/gpu_benchmark_155937_tid_0.o.0'},
#  {'cortex_density': '48',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 121.2,
#   'running_0_time': 17.58,
#   'running_1_cpu': 122.3,
#   'running_1_time': 17.62,
#   'running_full_cpu': 273.7,
#   'running_full_time': 21.92,
#   'startup_cpu': 96.8,
#   'startup_time': 1.92,
#   'tid': 1,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1559-gpu_benchmark/streams/gpu_benchmark_160049_tid_1.o.1'},
#  {'cortex_density': '48',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 98.7,
#   'running_0_time': 21.9,
#   'running_1_cpu': 102.9,
#   'running_1_time': 22.68,
#   'running_full_cpu': 442.2,
#   'running_full_time': 43.8,
#   'startup_cpu': 96.9,
#   'startup_time': 1.94,
#   'tid': 2,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1559-gpu_benchmark/streams/gpu_benchmark_160145_tid_2.o.2'},
#  {'cortex_density': '48',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 122.5,
#   'running_0_time': 17.1,
#   'running_1_cpu': 122.7,
#   'running_1_time': 17.62,
#   'running_full_cpu': 480.6,
#   'running_full_time': 35.92,
#   'startup_cpu': 90.1,
#   'startup_time': 1.04,
#   'tid': 3,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1559-gpu_benchmark/streams/gpu_benchmark_160312_tid_3.o.3'},
#  {'cortex_density': '142',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 99.8,
#   'running_0_time': 247.32,
#   'running_1_cpu': 100.2,
#   'running_1_time': 248.82,
#   'running_full_cpu': 164.7,
#   'running_full_time': 275.52,
#   'startup_cpu': 94.9,
#   'startup_time': 1.98,
#   'tid': 4,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1559-gpu_benchmark/streams/gpu_benchmark_160422_tid_4.o.4'},
#  {'cortex_density': '142',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 104.0,
#   'running_0_time': 111.12,
#   'running_1_cpu': 106.0,
#   'running_1_time': 114.8,
#   'running_full_cpu': 386.4,
#   'running_full_time': 188.34,
#   'startup_cpu': 89.5,
#   'startup_time': 1.1,
#   'tid': 5,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1559-gpu_benchmark/streams/gpu_benchmark_161712_tid_5.o.5'},
#  {'cortex_density': '142',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 99.8,
#   'running_0_time': 250.3,
#   'running_1_cpu': 100.1,
#   'running_1_time': 249.8,
#   'running_full_cpu': 301.1,
#   'running_full_time': 352.52,
#   'startup_cpu': 95.9,
#   'startup_time': 1.96,
#   'tid': 6,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1559-gpu_benchmark/streams/gpu_benchmark_162406_tid_6.o.6'},
#  {'cortex_density': '142',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 104.5,
#   'running_0_time': 110.6,
#   'running_1_cpu': 106.0,
#   'running_1_time': 112.34,
#   'running_full_cpu': 613.5,
#   'running_full_time': 424.2,
#   'startup_cpu': 88.6,
#   'startup_time': 1.12,
#   'tid': 7,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1559-gpu_benchmark/streams/gpu_benchmark_163819_tid_7.o.7'},
#  {'cortex_density': '48',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 98.7,
#   'running_0_time': 21.56,
#   'running_1_cpu': 103.3,
#   'running_1_time': 22.06,
#   'running_full_cpu': 241.5,
#   'running_full_time': 27.22,
#   'startup_cpu': 95.3,
#   'startup_time': 1.16,
#   'tid': 0,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1732-gpu_benchmark/streams/gpu_benchmark_173227_tid_0.o.0'},
#  {'cortex_density': '48',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 123.1,
#   'running_0_time': 16.02,
#   'running_1_cpu': 124.1,
#   'running_1_time': 16.08,
#   'running_full_cpu': 276.1,
#   'running_full_time': 21.44,
#   'startup_cpu': 95.9,
#   'startup_time': 1.96,
#   'tid': 1,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1732-gpu_benchmark/streams/gpu_benchmark_173338_tid_1.o.1'},
#  {'cortex_density': '48',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 99.2,
#   'running_0_time': 21.62,
#   'running_1_cpu': 103.1,
#   'running_1_time': 21.86,
#   'running_full_cpu': 450.3,
#   'running_full_time': 42.94,
#   'startup_cpu': 95.7,
#   'startup_time': 1.9,
#   'tid': 2,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1732-gpu_benchmark/streams/gpu_benchmark_173432_tid_2.o.2'},
#  {'cortex_density': '48',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 123.1,
#   'running_0_time': 16.16,
#   'running_1_cpu': 123.8,
#   'running_1_time': 16.58,
#   'running_full_cpu': 486.0,
#   'running_full_time': 35.16,
#   'startup_cpu': 96.7,
#   'startup_time': 1.86,
#   'tid': 3,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1732-gpu_benchmark/streams/gpu_benchmark_173558_tid_3.o.3'},
#  {'cortex_density': '142',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 99.8,
#   'running_0_time': 240.96,
#   'running_1_cpu': 100.2,
#   'running_1_time': 239.0,
#   'running_full_cpu': 167.1,
#   'running_full_time': 265.14,
#   'startup_cpu': 96.7,
#   'startup_time': 1.84,
#   'tid': 4,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1732-gpu_benchmark/streams/gpu_benchmark_173706_tid_4.o.4'},
#  {'cortex_density': '142',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 104.2,
#   'running_0_time': 108.6,
#   'running_1_cpu': 106.2,
#   'running_1_time': 107.76,
#   'running_full_cpu': 394.6,
#   'running_full_time': 184.58,
#   'startup_cpu': 94.7,
#   'startup_time': 1.92,
#   'tid': 5,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1732-gpu_benchmark/streams/gpu_benchmark_174931_tid_5.o.5'},
#  {'cortex_density': '142',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 99.8,
#   'running_0_time': 237.94,
#   'running_1_cpu': 100.2,
#   'running_1_time': 240.78,
#   'running_full_cpu': 308.1,
#   'running_full_time': 341.18,
#   'startup_cpu': 95.8,
#   'startup_time': 1.92,
#   'tid': 6,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1732-gpu_benchmark/streams/gpu_benchmark_175611_tid_6.o.6'},
#  {'cortex_density': '142',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 104.2,
#   'running_0_time': 106.88,
#   'running_1_cpu': 106.3,
#   'running_1_time': 107.28,
#   'running_full_cpu': 617.3,
#   'running_full_time': 410.1,
#   'startup_cpu': 96.6,
#   'startup_time': 1.8,
#   'tid': 7,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_1732-gpu_benchmark/streams/gpu_benchmark_180950_tid_7.o.7'},
#  {'cortex_density': '180',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 99.9,
#   'running_0_time': 516.44,
#   'running_1_cpu': 100.0,
#   'running_1_time': 516.28,
#   'running_full_cpu': 137.3,
#   'running_full_time': 571.42,
#   'startup_cpu': 76.7,
#   'startup_time': 2.36,
#   'tid': 0,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_2159-gpu_benchmark/streams/gpu_benchmark_215914_tid_0.o.0'},
#  {'cortex_density': '180',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 103.2,
#   'running_0_time': 176.68,
#   'running_1_cpu': 106.2,
#   'running_1_time': 175.12,
#   'running_full_cpu': 456.8,
#   'running_full_time': 356.3,
#   'startup_cpu': 95.7,
#   'startup_time': 1.88,
#   'tid': 1,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-08_2159-gpu_benchmark/streams/gpu_benchmark_222559_tid_1.o.1'},
#  {'cortex_density': '48',
#   'gpu': 'True',
#   'host': 'stonesoup.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 99.5,
#   'running_0_time': 35.94,
#   'running_1_cpu': 105.0,
#   'running_1_time': 35.32,
#   'running_full_cpu': 284.8,
#   'running_full_time': 38.3,
#   'startup_cpu': 98.6,
#   'startup_time': 1.86,
#   'tid': 0,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_0017-gpu_benchmark/streams/gpu_benchmark_001711_tid_0.o.0'},
#  {'cortex_density': '48',
#   'gpu': 'False',
#   'host': 'stonesoup.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 131.9,
#   'running_0_time': 25.14,
#   'running_1_cpu': 133.7,
#   'running_1_time': 24.46,
#   'running_full_cpu': 315.0,
#   'running_full_time': 30.68,
#   'startup_cpu': 92.1,
#   'startup_time': 2.04,
#   'tid': 1,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_0017-gpu_benchmark/streams/gpu_benchmark_001900_tid_1.o.1'},
#  {'cortex_density': '48',
#   'gpu': 'True',
#   'host': 'stonesoup.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 100.0,
#   'running_0_time': 31.78,
#   'running_1_cpu': 105.6,
#   'running_1_time': 32.76,
#   'running_full_cpu': 582.5,
#   'running_full_time': 57.6,
#   'startup_cpu': 98.5,
#   'startup_time': 1.82,
#   'tid': 2,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_0017-gpu_benchmark/streams/gpu_benchmark_002020_tid_2.o.2'},
#  {'cortex_density': '48',
#   'gpu': 'False',
#   'host': 'stonesoup.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 131.4,
#   'running_0_time': 24.76,
#   'running_1_cpu': 133.0,
#   'running_1_time': 24.68,
#   'running_full_cpu': 619.8,
#   'running_full_time': 43.88,
#   'startup_cpu': 97.9,
#   'startup_time': 1.86,
#   'tid': 3,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_0017-gpu_benchmark/streams/gpu_benchmark_002222_tid_3.o.3'},
#  {'cortex_density': '142',
#   'gpu': 'True',
#   'host': 'stonesoup.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 100.0,
#   'running_0_time': 400.04,
#   'running_1_cpu': 100.4,
#   'running_1_time': 403.16,
#   'running_full_cpu': 176.6,
#   'running_full_time': 432.42,
#   'startup_cpu': 97.9,
#   'startup_time': 1.86,
#   'tid': 4,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_0017-gpu_benchmark/streams/gpu_benchmark_002355_tid_4.o.4'},
#  {'cortex_density': '142',
#   'gpu': 'False',
#   'host': 'stonesoup.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 106.2,
#   'running_0_time': 166.28,
#   'running_1_cpu': 109.6,
#   'running_1_time': 169.72,
#   'running_full_cpu': 617.1,
#   'running_full_time': 311.78,
#   'startup_cpu': 97.2,
#   'startup_time': 1.92,
#   'tid': 5,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_0017-gpu_benchmark/streams/gpu_benchmark_004431_tid_5.o.5'},
#  {'cortex_density': '142',
#   'gpu': 'True',
#   'host': 'stonesoup.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 100.0,
#   'running_0_time': 401.36,
#   'running_1_cpu': 100.5,
#   'running_1_time': 398.86,
#   'running_full_cpu': 349.5,
#   'running_full_time': 530.2,
#   'startup_cpu': 98.6,
#   'startup_time': 1.9,
#   'tid': 6,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_0017-gpu_benchmark/streams/gpu_benchmark_005519_tid_6.o.6'},
#  {'cortex_density': '142',
#   'gpu': 'False',
#   'host': 'stonesoup.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 106.1,
#   'running_0_time': 164.38,
#   'running_1_cpu': 110.1,
#   'running_1_time': 165.26,
#   'running_full_cpu': 946.7,
#   'running_full_time': 726.86,
#   'startup_cpu': 97.1,
#   'startup_time': 1.84,
#   'tid': 7,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_0017-gpu_benchmark/streams/gpu_benchmark_011729_tid_7.o.7'}]

# %%
collected_timings.dframe
# Out:
#    cortex_density    gpu                    host iterations  running_0_cpu  \
# 0              48   True     melmac.inf.ed.ac.uk        250           99.0
# 1              48  False     melmac.inf.ed.ac.uk        250          121.2
# 2              48   True     melmac.inf.ed.ac.uk       1000           98.7
# 3              48  False     melmac.inf.ed.ac.uk       1000          122.5
# 4             142   True     melmac.inf.ed.ac.uk        250           99.8
# 5             142  False     melmac.inf.ed.ac.uk        250          104.0
# 6             142   True     melmac.inf.ed.ac.uk       1000           99.8
# 7             142  False     melmac.inf.ed.ac.uk       1000          104.5
# 8              48   True     melmac.inf.ed.ac.uk        250           98.7
# 9              48  False     melmac.inf.ed.ac.uk        250          123.1
# 10             48   True     melmac.inf.ed.ac.uk       1000           99.2
# 11             48  False     melmac.inf.ed.ac.uk       1000          123.1
# 12            142   True     melmac.inf.ed.ac.uk        250           99.8
# 13            142  False     melmac.inf.ed.ac.uk        250          104.2
# 14            142   True     melmac.inf.ed.ac.uk       1000           99.8
# 15            142  False     melmac.inf.ed.ac.uk       1000          104.2
# 16            180   True     melmac.inf.ed.ac.uk        250           99.9
# 17            180  False     melmac.inf.ed.ac.uk        250          103.2
# 18             48   True  stonesoup.inf.ed.ac.uk        250           99.5
# 19             48  False  stonesoup.inf.ed.ac.uk        250          131.9
# 20             48   True  stonesoup.inf.ed.ac.uk       1000          100.0
# 21             48  False  stonesoup.inf.ed.ac.uk       1000          131.4
# 22            142   True  stonesoup.inf.ed.ac.uk        250          100.0
# 23            142  False  stonesoup.inf.ed.ac.uk        250          106.2
# 24            142   True  stonesoup.inf.ed.ac.uk       1000          100.0
# 25            142  False  stonesoup.inf.ed.ac.uk       1000          106.1
#
#     running_0_time  running_1_cpu  running_1_time  running_full_cpu  \
# 0            22.42          102.8           22.74             240.9
# 1            17.58          122.3           17.62             273.7
# 2            21.90          102.9           22.68             442.2
# 3            17.10          122.7           17.62             480.6
# 4           247.32          100.2          248.82             164.7
# 5           111.12          106.0          114.80             386.4
# 6           250.30          100.1          249.80             301.1
# 7           110.60          106.0          112.34             613.5
# 8            21.56          103.3           22.06             241.5
# 9            16.02          124.1           16.08             276.1
# 10           21.62          103.1           21.86             450.3
# 11           16.16          123.8           16.58             486.0
# 12          240.96          100.2          239.00             167.1
# 13          108.60          106.2          107.76             394.6
# 14          237.94          100.2          240.78             308.1
# 15          106.88          106.3          107.28             617.3
# 16          516.44          100.0          516.28             137.3
# 17          176.68          106.2          175.12             456.8
# 18           35.94          105.0           35.32             284.8
# 19           25.14          133.7           24.46             315.0
# 20           31.78          105.6           32.76             582.5
# 21           24.76          133.0           24.68             619.8
# 22          400.04          100.4          403.16             176.6
# 23          166.28          109.6          169.72             617.1
# 24          401.36          100.5          398.86             349.5
# 25          164.38          110.1          165.26             946.7
#
#     running_full_time  startup_cpu  startup_time  tid  \
# 0               27.78         98.0          1.02    0
# 1               21.92         96.8          1.92    1
# 2               43.80         96.9          1.94    2
# 3               35.92         90.1          1.04    3
# 4              275.52         94.9          1.98    4
# 5              188.34         89.5          1.10    5
# 6              352.52         95.9          1.96    6
# 7              424.20         88.6          1.12    7
# 8               27.22         95.3          1.16    0
# 9               21.44         95.9          1.96    1
# 10              42.94         95.7          1.90    2
# 11              35.16         96.7          1.86    3
# 12             265.14         96.7          1.84    4
# 13             184.58         94.7          1.92    5
# 14             341.18         95.8          1.92    6
# 15             410.10         96.6          1.80    7
# 16             571.42         76.7          2.36    0
# 17             356.30         95.7          1.88    1
# 18              38.30         98.6          1.86    0
# 19              30.68         92.1          2.04    1
# 20              57.60         98.5          1.82    2
# 21              43.88         97.9          1.86    3
# 22             432.42         97.9          1.86    4
# 23             311.78         97.2          1.92    5
# 24             530.20         98.6          1.90    6
# 25             726.86         97.1          1.84    7
#
#                                          timing_files
# 0   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 1   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 2   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 3   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 4   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 5   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 6   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 7   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 8   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 9   /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 10  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 11  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 12  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 13  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 14  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 15  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 16  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 17  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 18  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 19  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 20  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 21  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 22  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 23  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 24  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...
# 25  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...

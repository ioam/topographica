# %%
import lancet, re

# %%
benchmark_name   = 'gpu_benchmark'
cortex_density = lancet.Range('cortex_density', 48, 142, steps=2, fp_precision=0)
iterations = lancet.Range('iterations', 250, 1000, steps=2, fp_precision=0)
resource=lancet.List('gpu',[True, False])  
executable = '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/timing_script.sh'
timing_cmd     = lancet.ShellCommand(executable=executable, posargs=['cortex_density', 'iterations', 'gpu'])
p_space = cortex_density * iterations* resource
# Runs locally. A Launcher could be used to launch jobs with Grid Engine.
lancet.Launcher(benchmark_name, p_space, timing_cmd, output_directory='benchmarks', max_concurrency=1)()
# Out:
# Time: 000000.00 Launcher: Group 0: executing 8 processes...

# %%
output_files   = lancet.FilePattern('timing_files', './benchmarks/*-gpu_benchmark*/streams/*_tid_{tid:d}.o*')

# %%
def parse_timings(filename):
    with open(filename, 'r') as infile:
        content = infile.read()
    
    host_m = re.search('^HOST:\t(?P<host>.*?)\n', content, re.MULTILINE)
    param_m = re.search('^PARAMS:\t(?P<cortex_density>.*?)\t(?P<iterations>.*?)\t(?P<gpu>.*?)\n', content, re.MULTILINE)
    version_m = re.search('^VERSION:\t(?P<version>.*?)\n', content, re.MULTILINE)
    timing_m = re.findall('^[0-9]*.[0-9]*u [0-9]*.[0-9]*s ([0-9]*:[0-9]*.[0-9]*) ([0-9]*.[0-9])%', content, re.MULTILINE)
    if host_m is None or param_m is None or len(timing_m) is not 4:
        raise Exception("The benchmark file %s has incorrect format" % filename)
    timing_m = [(float(t.split(':')[0]) * 60 + float(t.split(':')[1]) + float('0.' + t.split('.')[1]), float(u)) for t, u in timing_m]

    result = {'startup_time': timing_m[0][0], 'startup_cpu': timing_m[0][1],
              'running_0_time': timing_m[1][0], 'running_0_cpu': timing_m[1][1],
              'running_1_time': timing_m[2][0], 'running_1_cpu': timing_m[2][1],
              'running_full_time': timing_m[3][0], 'running_full_cpu': timing_m[3][1]}
    result.update(host_m.groupdict())
    result.update(param_m.groupdict())
    result.update(version_m.groupdict())
    return result

# %%
collected_timings = lancet.FileInfo(output_files, 'timing_files',
                                lancet.CustomFile(metadata_fn=parse_timings))

# %%
len(collected_timings)
# Out:
# 8

# %%
collected_timings.specs
# Out:
# [{'cortex_density': '48',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 97.8,
#   'running_0_time': 22.12,
#   'running_1_cpu': 103.4,
#   'running_1_time': 21.14,
#   'running_full_cpu': 243.8,
#   'running_full_time': 26.76,
#   'startup_cpu': 56.0,
#   'startup_time': 4.88,
#   'tid': 0,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_1936-gpu_benchmark/streams/gpu_benchmark_193635_tid_0.o.0',
#   'version': 'slow_elementwise_kernels'},
#  {'cortex_density': '48',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 123.0,
#   'running_0_time': 16.9,
#   'running_1_cpu': 124.1,
#   'running_1_time': 16.3,
#   'running_full_cpu': 275.7,
#   'running_full_time': 21.38,
#   'startup_cpu': 95.7,
#   'startup_time': 1.88,
#   'tid': 1,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_1936-gpu_benchmark/streams/gpu_benchmark_193748_tid_1.o.1',
#   'version': 'slow_elementwise_kernels'},
#  {'cortex_density': '48',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 99.1,
#   'running_0_time': 21.78,
#   'running_1_cpu': 103.3,
#   'running_1_time': 21.38,
#   'running_full_cpu': 453.9,
#   'running_full_time': 43.86,
#   'startup_cpu': 96.7,
#   'startup_time': 1.86,
#   'tid': 2,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_1936-gpu_benchmark/streams/gpu_benchmark_193842_tid_2.o.2',
#   'version': 'slow_elementwise_kernels'},
#  {'cortex_density': '48',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 123.2,
#   'running_0_time': 16.86,
#   'running_1_cpu': 124.2,
#   'running_1_time': 16.86,
#   'running_full_cpu': 488.2,
#   'running_full_time': 35.36,
#   'startup_cpu': 93.8,
#   'startup_time': 1.94,
#   'tid': 3,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_1936-gpu_benchmark/streams/gpu_benchmark_194008_tid_3.o.3',
#   'version': 'slow_elementwise_kernels'},
#  {'cortex_density': '142',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 99.8,
#   'running_0_time': 238.44,
#   'running_1_cpu': 100.2,
#   'running_1_time': 240.14,
#   'running_full_cpu': 167.1,
#   'running_full_time': 265.12,
#   'startup_cpu': 96.7,
#   'startup_time': 1.86,
#   'tid': 4,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_1936-gpu_benchmark/streams/gpu_benchmark_194115_tid_4.o.4',
#   'version': 'slow_elementwise_kernels'},
#  {'cortex_density': '142',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '250',
#   'running_0_cpu': 104.0,
#   'running_0_time': 108.5,
#   'running_1_cpu': 106.3,
#   'running_1_time': 106.22,
#   'running_full_cpu': 393.8,
#   'running_full_time': 183.62,
#   'startup_cpu': 97.8,
#   'startup_time': 1.88,
#   'tid': 5,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_1936-gpu_benchmark/streams/gpu_benchmark_195339_tid_5.o.5',
#   'version': 'slow_elementwise_kernels'},
#  {'cortex_density': '142',
#   'gpu': 'True',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 99.8,
#   'running_0_time': 240.12,
#   'running_1_cpu': 100.2,
#   'running_1_time': 238.82,
#   'running_full_cpu': 307.7,
#   'running_full_time': 342.12,
#   'startup_cpu': 96.8,
#   'startup_time': 1.88,
#   'tid': 6,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_1936-gpu_benchmark/streams/gpu_benchmark_200017_tid_6.o.6',
#   'version': 'slow_elementwise_kernels'},
#  {'cortex_density': '142',
#   'gpu': 'False',
#   'host': 'melmac.inf.ed.ac.uk',
#   'iterations': '1000',
#   'running_0_cpu': 104.1,
#   'running_0_time': 108.04,
#   'running_1_cpu': 106.3,
#   'running_1_time': 107.36,
#   'running_full_cpu': 617.4,
#   'running_full_time': 412.62,
#   'startup_cpu': 95.8,
#   'startup_time': 1.94,
#   'tid': 7,
#   'timing_files': '/afs/inf.ed.ac.uk/user/s11/s1137931/honours/topographica/benchmarks/2015-02-09_1936-gpu_benchmark/streams/gpu_benchmark_201359_tid_7.o.7',
#   'version': 'slow_elementwise_kernels'}]

# %%
collected_timings.dframe
# Out:
#   cortex_density    gpu                 host iterations  running_0_cpu  \
# 0             48   True  melmac.inf.ed.ac.uk        250           97.8
# 1             48  False  melmac.inf.ed.ac.uk        250          123.0
# 2             48   True  melmac.inf.ed.ac.uk       1000           99.1
# 3             48  False  melmac.inf.ed.ac.uk       1000          123.2
# 4            142   True  melmac.inf.ed.ac.uk        250           99.8
# 5            142  False  melmac.inf.ed.ac.uk        250          104.0
# 6            142   True  melmac.inf.ed.ac.uk       1000           99.8
# 7            142  False  melmac.inf.ed.ac.uk       1000          104.1
#
#    running_0_time  running_1_cpu  running_1_time  running_full_cpu  \
# 0           22.12          103.4           21.14             243.8
# 1           16.90          124.1           16.30             275.7
# 2           21.78          103.3           21.38             453.9
# 3           16.86          124.2           16.86             488.2
# 4          238.44          100.2          240.14             167.1
# 5          108.50          106.3          106.22             393.8
# 6          240.12          100.2          238.82             307.7
# 7          108.04          106.3          107.36             617.4
#
#    running_full_time  startup_cpu  startup_time  tid  \
# 0              26.76         56.0          4.88    0
# 1              21.38         95.7          1.88    1
# 2              43.86         96.7          1.86    2
# 3              35.36         93.8          1.94    3
# 4             265.12         96.7          1.86    4
# 5             183.62         97.8          1.88    5
# 6             342.12         96.8          1.88    6
# 7             412.62         95.8          1.94    7
#
#                                         timing_files                   version
# 0  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...  slow_elementwise_kernels
# 1  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...  slow_elementwise_kernels
# 2  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...  slow_elementwise_kernels
# 3  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...  slow_elementwise_kernels
# 4  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...  slow_elementwise_kernels
# 5  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...  slow_elementwise_kernels
# 6  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...  slow_elementwise_kernels
# 7  /afs/inf.ed.ac.uk/user/s11/s1137931/honours/to...  slow_elementwise_kernels
